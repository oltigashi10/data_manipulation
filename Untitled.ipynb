# %%
import pandas as pd

# %%
data = pd.read_csv('sug.csv')

# %%
data
# Out:
#                    suggested discipline one  \
# 0                    Machine Learning, 74.4
# 1                          Accounting, 62.5
# 2                  Education Research, 70.3
# 3                   Addiction Studies, 57.1
# 4                  Actuarial Science, 100.0
# ...                                     ...
# 3886  Materials Science & Engineering, 27.8
# 3887  Materials Science & Engineering, 27.4
# 3888  Materials Science & Engineering, 33.3
# 3889                         Zoology, 100.0
# 3890           Humanities and Culture, 39.3
#
#                 suggested discipline two  \
# 0            Aerospace Engineering, 54.2
# 1           Communication Sciences, 50.0
# 2                       Accounting, 69.0
# 3             Addiction Counseling, 52.6
# 4            Agricultural Sciences, 78.9
# ...                                  ...
# 3886  Physical and Sport Education, 26.8
# 3887       Medicine and Healthcare, 25.7
# 3888     Manufacturing Engineering, 33.3
# ...

# %%
data['suggested discipline five'] =  data['suggested discipline five'].str.replace('\d+', '')
data['suggested discipline four'] =  data['suggested discipline four'].str.replace('\d+', '')
data['suggested discipline three'] =  data['suggested discipline three'].str.replace('\d+', '')
data['suggested discipline two'] =  data['suggested discipline two'].str.replace('\d+', '')
data['suggested discipline one'] =  data['suggested discipline one'].str.replace('\d+', '')
# Out:
# <ipython-input-91-4465631ff54c>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['suggested discipline five'] =  data['suggested discipline five'].str.replace('\d+', '')
# <ipython-input-91-4465631ff54c>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['suggested discipline four'] =  data['suggested discipline four'].str.replace('\d+', '')
# <ipython-input-91-4465631ff54c>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['suggested discipline three'] =  data['suggested discipline three'].str.replace('\d+', '')
# <ipython-input-91-4465631ff54c>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['suggested discipline two'] =  data['suggested discipline two'].str.replace('\d+', '')
# ...

# %%
 data['suggested discipline one']
# Out:
# 0                      Machine Learning, .
# 1                            Accounting, .
# 2                    Education Research, .
# 3                     Addiction Studies, .
# 4                     Actuarial Science, .
#                        ...
# 3886    Materials Science & Engineering, .
# 3887    Materials Science & Engineering, .
# 3888    Materials Science & Engineering, .
# 3889                            Zoology, .
# 3890             Humanities and Culture, .
# Name: suggested discipline one, Length: 3891, dtype: object

# %%
data
# Out:
#                 suggested discipline one         suggested discipline two  \
# 0                    Machine Learning, .         Aerospace Engineering, .
# 1                          Accounting, .        Communication Sciences, .
# 2                  Education Research, .                    Accounting, .
# 3                   Addiction Studies, .          Addiction Counseling, .
# 4                   Actuarial Science, .         Agricultural Sciences, .
# ...                                  ...                              ...
# 3886  Materials Science & Engineering, .  Physical and Sport Education, .
# 3887  Materials Science & Engineering, .       Medicine and Healthcare, .
# 3888  Materials Science & Engineering, .     Manufacturing Engineering, .
# 3889                          Zoology, .                     Sociology, .
# 3890           Humanities and Culture, .             Drama and Theater, .
#
#                suggested discipline three           suggested discipline four  \
# ...

# %%
data
# Out:
#                 suggested discipline one         suggested discipline two  \
# 0                    Machine Learning, .         Aerospace Engineering, .
# 1                          Accounting, .        Communication Sciences, .
# 2                  Education Research, .                    Accounting, .
# 3                   Addiction Studies, .          Addiction Counseling, .
# 4                   Actuarial Science, .         Agricultural Sciences, .
# ...                                  ...                              ...
# 3886  Materials Science & Engineering, .  Physical and Sport Education, .
# 3887  Materials Science & Engineering, .       Medicine and Healthcare, .
# 3888  Materials Science & Engineering, .     Manufacturing Engineering, .
# 3889                          Zoology, .                     Sociology, .
# 3890           Humanities and Culture, .             Drama and Theater, .
#
#                suggested discipline three           suggested discipline four  \
# ...

# %%
data['sug. one'] = data['sug. one'].map(lambda x: str(x)[:-5])
data['sug. two'] = data['sug. two'].map(lambda x: str(x)[:-5])
data['sug. three'] = data['sug. three'].map(lambda x: str(x)[:-5])
data['sug. four'] = data['sug. four'].map(lambda x: str(x)[:-5])
data['sug. five'] = data['sug. five'].map(lambda x: str(x)[:-5])

# %%
data
# Out:
#                                     sug. one  \
# 0                    Supply Chain Management
# 1                       Financial Management
# 2                                Electronics
# 3       Geographical Information Systems GIS
# 4                   Organizational Behaviour
# ...                                      ...
# 2885            Physical and Sport Education
# 2886       Real Estate & Property Management
# 2887  Environmental Studies & Earth Sciences
# 2888                                Zoology
# 2889                Education in Health Care
#
#                                   sug. two  \
# 0                      Aviation Management
# 1                        Health Management
# 2                             Mechatronics
# 3                            Arts & Design
# 4                   Humanities and Culture
# ...                                    ...
# 2885                     Special Education
# 2886                  Professional Studies
# ...

# %%
data.to_csv('names_data_to_fix.csv')

# %%
data = pd.read_csv('data_to_fix.csv')

# %%
data['sug. one'] =  data['sug. one'].str.replace('\d+', '')
data['sug. two'] =  data['sug. two'].str.replace('\d+', '')
data['sug. three'] =  data['sug. three'].str.replace('\d+', '')
data['sug. four'] =  data['sug. four'].str.replace('\d+', '')
data['sug. five'] =  data['sug. five'].str.replace('\d+', '')
# Out:
# <ipython-input-81-8b14d9fba83d>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['sug. one'] =  data['sug. one'].str.replace('\d+', '')
# <ipython-input-81-8b14d9fba83d>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['sug. two'] =  data['sug. two'].str.replace('\d+', '')
# <ipython-input-81-8b14d9fba83d>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['sug. three'] =  data['sug. three'].str.replace('\d+', '')
# <ipython-input-81-8b14d9fba83d>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['sug. four'] =  data['sug. four'].str.replace('\d+', '')
# <ipython-input-81-8b14d9fba83d>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['sug. five'] =  data['sug. five'].str.replace('\d+', '')

# %%
data
# Out:
#                                          sug. one  \
# 0                    Supply Chain Management 57.6
# 1                       Financial Management 65.4
# 2                                Electronics 84.6
# 3       Geographical Information Systems GIS 16.5
# 4                   Organizational Behaviour 40.9
# ...                                           ...
# 2885            Physical and Sport Education 38.2
# 2886       Real Estate & Property Management 33.6
# 2887  Environmental Studies & Earth Sciences 15.8
# 2888                                Zoology 100.0
# 2889                Education in Health Care 20.4
#
#                                        sug. two  \
# 0                      Aviation Management 54.5
# 1                        Health Management 57.1
# 2                             Mechatronics 66.7
# 3                            Arts & Design 12.9
# 4                   Humanities and Culture 39.5
# ...                                         ...
# ...

# %%
data['perc. two'] = data['sug. two'].str[-5:]
data['perc. three'] = data['sug. three'].str[-5:]
data['perc. four'] = data['sug. four'].str[-5:]
data['perc. five'] = data['sug. five'].str[-5:]

# %%
data.to_csv('numbers.to_csv')

# %%
data
# Out:
#                                          sug. one  \
# 0                    Supply Chain Management 57.6
# 1                       Financial Management 65.4
# 2                                Electronics 84.6
# 3       Geographical Information Systems GIS 16.5
# 4                   Organizational Behaviour 40.9
# ...                                           ...
# 2885            Physical and Sport Education 38.2
# 2886       Real Estate & Property Management 33.6
# 2887  Environmental Studies & Earth Sciences 15.8
# 2888                                Zoology 100.0
# 2889                Education in Health Care 20.4
#
#                                        sug. two  \
# 0                      Aviation Management 54.5
# 1                        Health Management 57.1
# 2                             Mechatronics 66.7
# 3                            Arts & Design 12.9
# 4                   Humanities and Culture 39.5
# ...                                         ...
# ...

# %%
data.to_csv('percentage.csv')
